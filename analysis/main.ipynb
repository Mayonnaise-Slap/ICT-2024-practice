# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
article_data = pd.read_json('../data/articles.json')

# %%
g = sns.barplot(article_data.explode('tags')["tags"].value_counts().head(15))
locs, labels = plt.xticks()

_ = g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# /var/folders/82/8g_0rbdn4_x9dq7f41hyyzsc0000gn/T/ipykernel_1817/2867413327.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')

# %%
user_data = pd.read_json('../data/users.json')

# %%
user_data["Работает в"].value_counts()
# Out:
# Работает в
# Open Data Science                                                                             63
# Яндекс                                                                                        50
# VK                                                                                            29
# RUVDS.com                                                                                     20
# TINKOFF                                                                                       18
#                                                                                               ..
# Яндекс\n      \n        ЮMoney\n      \n        Яндекс Практикум                               1
# Газпромбанк                                                                                    1
# GlobalSign                                                                                     1
# ...

# %%
user_data["Состоит в хабах"].dropna().explode().value_counts()
# Out:
# Состоит в хабах
# DIY                           2476
# AR and VR                     1871
# *nix                          1833
# IT-companies                  1818
# Big Data                      1710
#                               ...
# CRM-системы                      1
# Zig                              1
# Development for Office 365       1
# Operating systems                1
# Phalcon                          1
# Name: count, Length: 444, dtype: int64

# %%
user_data
# Out:
#                    tag  karma  rating    В рейтинге Зарегистрирован  \
# 0     @kirillkirill000    0.0     0.0  Не участвует      2017-10-14
# 1              @eresik   27.0     0.0  Не участвует      2010-05-11
# 2             @zamboga    2.0     0.0  Не участвует      2012-06-25
# 3           @ParaPilot    3.0     0.0  Не участвует      2013-04-12
# 4              @Ezik85    4.0     0.0  Не участвует      2011-10-10
# ...                ...    ...     ...           ...             ...
# 8026              @BJM    4.0     0.0  Не участвует      2018-02-27
# 8027        @maksasila   -3.0     0.0  Не участвует      2006-10-01
# 8028          @Tempest    0.0     0.0  Не участвует      2011-10-17
# 8029     @speakingfish   15.0     0.0  Не участвует      2013-03-01
# 8030          @ILLANOV    1.0     0.0  Не участвует      2024-01-18
#
#                                                Значки  \
# 0                 Бета-тестер ▇▅▄▅▅▄ ▇▄▅ Знаток Хабра
# ...
