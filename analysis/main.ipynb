# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_json('../data/articles.json')

# %%
g = sns.barplot(data.explode('tags')["tags"].value_counts().head(15))
locs, labels = plt.xticks()

_ = g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# /var/folders/82/8g_0rbdn4_x9dq7f41hyyzsc0000gn/T/ipykernel_81483/690913186.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
